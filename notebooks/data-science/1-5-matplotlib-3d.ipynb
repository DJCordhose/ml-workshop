# %% [markdown]
# <a href="https://colab.research.google.com/github/DJCordhose/ml-workshop/blob/master/notebooks/data-science/1-5-matplotlib-3d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Plotting in 3d
#
# * https://matplotlib.org/mpl_toolkits/mplot3d/tutorial.html
# * https://matplotlib.org/api/_as_gen/matplotlib.figure.Figure.html#matplotlib.figure.Figure.add_subplot

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# for interactive 3d on local jupyer notebook
# %matplotlib notebook

# %%
from sklearn import datasets

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
n_points = 1000
X, _ = datasets.samples_generator.make_s_curve(n_points, random_state=0)

# %%
fig = plt.figure(figsize=(8, 8))
fig.suptitle("The disconnected S Curve with %i points"
             % (n_points), fontsize=20)

# ax = fig.add_subplot(111, projection='3d')
# ax = fig.add_subplot(1, 1, 1, projection='3d')
nrows=1
ncols=1
index=1
ax = fig.add_subplot(nrows, ncols, index, projection='3d')
ax.scatter(X[:, 0], X[:, 1], X[:, 2])

# https://en.wikipedia.org/wiki/Azimuth
ax.view_init(elev=10, azim=-60)

# %% [markdown]
# # Exercise: experiment with elevation and azimuth to get a better impression of how our S looks like
#
# * samples further away from the view point are shaded to give an impression of depth. Can you find out where to change that?
