# %% [markdown]
# # Matplotlib Hello World

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
plt.plot([1, 2, 3, 4], [10, 20, 25, 30])

# %%
plt.scatter([1, 2, 3, 4], [10, 20, 25, 30], color='red')

# %% [markdown]
# ## Exercise
#
# ### Execute this notebook and get familiar with its state-based API
#
# * You can execute each cell by hitting shift+enter
# * You will need some of the documentation which you get by putting a questionmark after the API Call
#
# Execute the next cell to load the exercise. If you rather want to see the solution change the load path to contain 'solution' instead of 'exercise.
#
# _If you are on Colab:_ %load does not seem to work on Colab, so simply copy and paste from the URL provided below.

# %%
# on Colab simply open and copy paste from
# https://raw.githubusercontent.com/DJCordhose/data-viz/master/notebooks/exercise/matplotlib-hello-world.py

# %load exercise/matplotlib-hello-world.py
