# %% [markdown]
# # Pandas with Seaborn

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.1.0

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 0.23.4

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.16.4

# %%
import seaborn as sns
print(sns.__version__)
# Out:
# 0.9.0

# %% [markdown]
# ## Loading and exploring our data set
# This is a database of customers of an insurance company. Each data point is one customer. The group represents the number of accidents the customer has been involved with in the past
#
# * 0 - red: many accidents
# * 1 - blue: no accidents
# * 2 - yellow: few accidents

# %%
df = pd.read_csv('https://raw.githubusercontent.com/DJCordhose/data-viz/master/data/insurance-customers-1500.csv', sep=';')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1500, 4)

# %%
type(df.values)
# Out:
# numpy.ndarray

# %%
df.describe()
# Out:
#              speed          age        miles        group
# count  1500.000000  1500.000000  1500.000000  1500.000000
# mean    122.492667    44.980667    30.434000     0.998667
# std      17.604333    17.130400    15.250815     0.816768
# min      68.000000    16.000000     1.000000     0.000000
# 25%     108.000000    32.000000    18.000000     0.000000
# 50%     120.000000    42.000000    29.000000     1.000000
# 75%     137.000000    55.000000    42.000000     2.000000
# max     166.000000   100.000000    84.000000     2.000000

# %% [markdown]
# ## A pairplot of a few samples gives you a nice overview of your data

# %%
sample_df = df.sample(n=100, random_state=42)
sns.pairplot(sample_df, hue="group", palette={0: '#AA4444', 1: '#000060', 2: '#EEEE44'})
