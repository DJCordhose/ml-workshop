# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/DJCordhose/data-viz/blob/master/notebooks/2-4-matplotlib-3d.ipynb)

# %% [markdown]
# # Plotting in 3d

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# for interactive 3d on local jupyer notebook
# %matplotlib notebook
# %matplotlib inline

# %%
from sklearn import datasets

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
n_points = 1000
X, _ = datasets.samples_generator.make_s_curve(n_points, random_state=0)

# %%
fig = plt.figure(figsize=(5, 5))
fig.suptitle("The disconnected S Curve with %i points"
             % (n_points), fontsize=24)

# ax = fig.add_subplot(111, projection='3d')
# ax = fig.add_subplot(1, 1, 1, projection='3d')
nrows=1
ncols=1
index=1
ax = fig.add_subplot(nrows, ncols, index, projection='3d')
ax.scatter(X[:, 0], X[:, 1], X[:, 2])

# https://en.wikipedia.org/wiki/Azimuth
ax.view_init(elev=10, azim=-60)

# for interactive 3don local jupyer notebook
# fig.show()
# Out:
# <img src="data:image/png;base64,..." width="499.9999891627921">

# %%
# fig.add_subplot?

# %%
# plt.subplot?
